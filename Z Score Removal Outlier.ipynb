# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('loan.csv')

# %%
df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
df.shape
# Out:
# (614, 13)

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
sns.boxplot(x = df["CoapplicantIncome"])
plt.show()

# %%
sns.distplot(df['CoapplicantIncome'])
plt.show()
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_3872\1457747018.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['CoapplicantIncome'])

# %%
min_range = (df['CoapplicantIncome'].mean())-(3*df['CoapplicantIncome'].std())
max_range = (df['CoapplicantIncome'].mean())+(3*df['CoapplicantIncome'].std())

# %%
min_range,max_range
# Out:
# (-7157.4993096454655, 10399.990905699668)

# %%
new_data = df[df['CoapplicantIncome']<=max_range]

# %%
new_data.shape
# Out:
# (608, 13)

# %%
sns.boxplot(x=new_data['CoapplicantIncome'])
plt.show()

# %% [markdown]
# Now using Z score method

# %%
z_score = (df['CoapplicantIncome'] - df['CoapplicantIncome'].mean())/(df['CoapplicantIncome'].std())
z_score
# Out:
# 0     -0.554036
# 1     -0.038700
# 2     -0.554036
# 3      0.251774
# 4     -0.554036
#          ...
# 609   -0.554036
# 610   -0.554036
# 611   -0.472019
# 612   -0.554036
# 613   -0.554036
# Name: CoapplicantIncome, Length: 614, dtype: float64

# %%
df["z_score"] = z_score

# %%
df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status   z_score
# 0             1.0         Urban           Y -0.554036
# 1             1.0         Rural           N -0.038700
# 2             1.0         Urban           Y -0.554036

# %%
new_data1 = df[df['z_score']<3]

# %%
sns.boxplot(x=new_data1['CoapplicantIncome'])
plt.show()

# %% [markdown]
# # Practicing

# %%
sns.distplot(df['ApplicantIncome'])
plt.show()
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_3872\3385199946.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ApplicantIncome'])

# %%
q1 = df['ApplicantIncome'].quantile(0.25)
q3 = df['ApplicantIncome'].quantile(0.75)

# %%
iqr = q3-q1
iqr
# Out:
# 2054.75

# %%
l = q1-(1.5*iqr)
h = q3+(1.5*iqr)

# %%
l,h
# Out:
# (-317.125, 7901.875)

# %%
df = df[df['ApplicantIncome'] <= h]

# %%
sns.boxplot(df['ApplicantIncome'])
plt.show()

# %%
sns.distplot(df['ApplicantIncome'])
plt.show()
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_3872\3385199946.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ApplicantIncome'])

# %%
df_cols = df.select_dtypes(include='number')
df_cols
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# 6               2333             1516.0        95.0             360.0
# ..               ...                ...         ...               ...
# 603             3676             4301.0       172.0             360.0
# 606             3400             2500.0       173.0             360.0
# 607             3987             1411.0       157.0             360.0
# 608             3232             1950.0       108.0             360.0
# 609             2900                0.0        71.0             360.0
#
#      Credit_History   z_score
# 1               1.0 -0.038700
# 2               1.0 -0.554036
# 3               1.0  0.251774
# ...

# %%
for i in df_cols:
    sns.distplot(df[i])
    plt.show()
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_3872\812767060.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# C:\Users\ankit\AppData\Local\Temp\ipykernel_3872\812767060.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# ...

# %% [markdown]
# ## after removing outlier col is

# %%
for col in df_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3-Q1
    min_range = Q1-(1.5*IQR)
    max_range = Q3+(1.5*IQR)
    df = df[df[col] <= max_range]

# %%
for i in df.select_dtypes(include='number'):
    sns.distplot(df[i])
    plt.show()
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_3872\4196345498.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# C:\Users\ankit\AppData\Local\Temp\ipykernel_3872\4196345498.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# ...

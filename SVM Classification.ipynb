# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
df = pd.read_csv('SVM Classification.csv')

# %%
df.head()
# Out:
#    Feature1  Feature2  Target
# 0  0.204760 -0.357665       0
# 1 -1.381197  1.390041       0
# 2  0.564351  0.467320       1
# 3  1.130436  0.496788       1
# 4  0.230647 -0.344902       0

# %%
df.isnull().sum()
# Out:
# Feature1    0
# Feature2    0
# Target      0
# dtype: int64

# %%
sns.scatterplot(x = 'Feature1', y = 'Feature2', data = df, hue = 'Target')
plt.show()

# %%
x = df.iloc[:,:-1]
y = df['Target']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVC

# %%
sv = SVC(kernel= 'linear')

# %%
sv.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
sv.score(x_test, y_test)*100
# Out:
# 98.35000000000001

# %%
sv.score(x_train, y_train)*100
# Out:
# 97.7

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=sv)
plt.show()
# Out:
# C:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

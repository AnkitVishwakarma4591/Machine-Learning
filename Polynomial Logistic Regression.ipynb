# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('polynomial_logistic_regression_data.csv')

# %%
df.head()
# Out:
#          X1        X2        X3  X1_squared  X2_squared      X1_X2  Output
# 0 -2.509198 -4.483183  2.534026    6.296073   20.098928  11.249192       0
# 1  9.014286  0.313546  4.178855   81.257354    0.098311   2.826396       0
# 2  4.639879  0.406351  2.655157   21.528476    0.165121   1.885420       1
# 3  1.973170  1.374299  1.330538    3.893399    1.888698   2.711725       1
# 4 -6.879627  2.260913  1.809538   47.329270    5.111729 -15.554241       0

# %%
df.isnull().sum()
# Out:
# X1            0
# X2            0
# X3            0
# X1_squared    0
# X2_squared    0
# X1_X2         0
# Output        0
# dtype: int64

# %%
sns.scatterplot(x =df['X1'], y=df['X2_squared'] ,hue = df['Output'])
plt.show()

# %%
sns.pairplot(data=df,hue='Output')
plt.show()

# %%
x = df.iloc[:,:-1]
y = df['Output']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 98.33333333333333

# %% [markdown]
# # Testing upon two column

# %% [markdown]
# # using simple logistic regression

# %%
df.select_dtypes(include='float64').columns
# Out:
# Index(['X1', 'X2', 'X3', 'X1_squared', 'X2_squared', 'X1_X2'], dtype='object')

# %%
x = df[['X1','X2_squared']]

# %%
y = df['Output']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 63.33333333333333

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=lr)
plt.show()
# Out:
# C:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Testing same data using polynomial logistic regression

# %%
sns.scatterplot(x =df['X1'], y=df['X2_squared'] ,hue = df['Output'])
plt.show()

# %%
x = df.iloc[:,:-1]

# %%
y = df['Output']

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf  = PolynomialFeatures(degree=2)

# %%
pf.fit(x)
# Out:
# PolynomialFeatures()

# %%
x = pd.DataFrame(pf.transform(x))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 98.33333333333333
